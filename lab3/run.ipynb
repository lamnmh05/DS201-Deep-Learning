# %%
# !python -m main --task 1
# Out:
# [25/11/2025 08:58:49] INFO: Creating vocab
# [25/11/2025 08:58:51] INFO: Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 94.22it/s, loss=0.4897]
# [25/11/2025 08:59:02] INFO: [Epoch 1] Val_loss=0.4897 | Val_Macro-F1=0.5184
# [25/11/2025 08:59:02] INFO: New BEST model saved (F1=0.5184)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 87.62it/s, loss=0.4466]
# [25/11/2025 08:59:09] INFO: [Epoch 2] Val_loss=0.4287 | Val_Macro-F1=0.6576
# [25/11/2025 08:59:09] INFO: New BEST model saved (F1=0.6576)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 93.19it/s, loss=0.4056]
# [25/11/2025 08:59:16] INFO: [Epoch 3] Val_loss=0.4056 | Val_Macro-F1=0.6808
# [25/11/2025 08:59:16] INFO: New BEST model saved (F1=0.6808)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 94.85it/s, loss=0.3826]
# [25/11/2025 08:59:24] INFO: [Epoch 4] Val_loss=0.3826 | Val_Macro-F1=0.7269
# ...

# %%
# !python -m main --task 2
# Out:
# [25/11/2025 09:07:05] INFO: Creating vocab
# [25/11/2025 09:07:07] INFO: Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 99.40it/s, loss=0.3484]
# [25/11/2025 09:07:15] INFO: [Epoch 1] Val_loss=0.2996 | Val_Macro-F1=0.7125
# [25/11/2025 09:07:15] INFO: New BEST model saved (F1=0.7125)
# ...
# Validating: 100%|███████████████████████████| 50/50 [00:00<00:00, 100.67it/s, loss=0.3185]
# [25/11/2025 09:07:22] INFO: [Epoch 2] Val_loss=0.2739 | Val_Macro-F1=0.7284
# [25/11/2025 09:07:22] INFO: New BEST model saved (F1=0.7284)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 97.27it/s, loss=0.3093]
# [25/11/2025 09:07:29] INFO: [Epoch 3] Val_loss=0.2660 | Val_Macro-F1=0.7755
# [25/11/2025 09:07:29] INFO: New BEST model saved (F1=0.7755)
# ...
# Validating: 100%|████████████████████████████| 50/50 [00:00<00:00, 99.58it/s, loss=0.3337]
# [25/11/2025 09:07:36] INFO: [Epoch 4] Val_loss=0.2870 | Val_Macro-F1=0.7758
# ...

# %%
# !python -m main --task 3
# Out:
# [25/11/2025 09:04:17] INFO: Creating vocab
# [25/11/2025 09:04:17] INFO: Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 63/63 [00:01<00:00, 57.46it/s, loss=0.5635]
# [25/11/2025 09:04:27] INFO: [Epoch 1] Val_loss=0.5367 | Val_Macro-F1=0.2115
# [25/11/2025 09:04:27] INFO: New BEST model saved (F1=0.2115)
# ...
# Validating: 100%|████████████████████████████| 63/63 [00:01<00:00, 57.06it/s, loss=0.2918]
# [25/11/2025 09:04:34] INFO: [Epoch 2] Val_loss=0.2686 | Val_Macro-F1=0.4605
# [25/11/2025 09:04:34] INFO: New BEST model saved (F1=0.4605)
# ...
# Validating: 100%|████████████████████████████| 63/63 [00:01<00:00, 57.71it/s, loss=0.1799]
# [25/11/2025 09:04:42] INFO: [Epoch 3] Val_loss=0.1714 | Val_Macro-F1=0.6013
# [25/11/2025 09:04:42] INFO: New BEST model saved (F1=0.6013)
# ...
# Validating: 100%|████████████████████████████| 63/63 [00:01<00:00, 57.22it/s, loss=0.1586]
# [25/11/2025 09:04:50] INFO: [Epoch 4] Val_loss=0.1510 | Val_Macro-F1=0.6795
# ...
