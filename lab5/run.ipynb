# %%
# !pip install idx2numpy -q
# !git clone https://github.com/lamnmh05/DS201-Deep-Learning.git
# Out:
# Cloning into 'DS201-Deep-Learning'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 201 (delta 14), reused 40 (delta 14), pack-reused 159 (from 1)
# Receiving objects: 100% (201/201), 284.44 MiB | 44.63 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# Updating files: 100% (99/99), done.

# %%
cd DS201-Deep-Learning/lab5
# Out:
# /kaggle/working/DS201-Deep-Learning/lab5

# %%
/kaggle/working/DS201-Deep-Learning/lab5/src/data/UIT_ViOCD/dev_preprocessed.json

# %%
# !python -m main --task 1
# Out:
# [01/01/2026 11:51:32] INFO: Creating vocab
# [01/01/2026 11:51:34] INFO: Loading datasets & dataloaders
# ...
# Validating: 100%|████████████████████████████| 18/18 [00:00<00:00, 45.73it/s, loss=0.6964]
# [01/01/2026 11:51:43] INFO: [Epoch 1] Val_loss=0.6190 | Val_Macro-F1=0.6001
# [01/01/2026 11:51:43] INFO: New BEST model saved (F1=0.6001)
# ...
# Validating: 100%|████████████████████████████| 18/18 [00:00<00:00, 42.98it/s, loss=0.5262]
# [01/01/2026 11:51:48] INFO: [Epoch 2] Val_loss=0.4677 | Val_Macro-F1=0.7724
# [01/01/2026 11:51:48] INFO: New BEST model saved (F1=0.7724)
# ...
# Validating: 100%|████████████████████████████| 18/18 [00:00<00:00, 46.17it/s, loss=0.4379]
# [01/01/2026 11:51:54] INFO: [Epoch 3] Val_loss=0.3892 | Val_Macro-F1=0.8070
# [01/01/2026 11:51:54] INFO: New BEST model saved (F1=0.8070)
# ...
# Validating: 100%|████████████████████████████| 18/18 [00:00<00:00, 46.00it/s, loss=0.4285]
# [01/01/2026 11:51:59] INFO: [Epoch 4] Val_loss=0.3808 | Val_Macro-F1=0.8244
# ...

# %%
# !python -m main --task 2
# Out:
# [01/01/2026 11:52:47] INFO: Creating vocab
# [01/01/2026 11:52:47] INFO: Loading datasets & dataloaders
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 115.97it/s, loss=0.4437]
# [01/01/2026 11:52:53] INFO: [Epoch 1] Val_loss=0.4296 | Val_Macro-F1=0.4755
# [01/01/2026 11:52:53] INFO: New BEST model saved (F1=0.4755)
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 117.48it/s, loss=0.3372]
# [01/01/2026 11:52:58] INFO: [Epoch 2] Val_loss=0.3265 | Val_Macro-F1=0.5927
# [01/01/2026 11:52:58] INFO: New BEST model saved (F1=0.5927)
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 116.10it/s, loss=0.3423]
# [01/01/2026 11:53:02] INFO: [Epoch 3] Val_loss=0.3315 | Val_Macro-F1=0.6170
# [01/01/2026 11:53:02] INFO: New BEST model saved (F1=0.6170)
# ...
# Validating: 100%|███████████████████████████| 63/63 [00:00<00:00, 116.52it/s, loss=0.3278]
# [01/01/2026 11:53:06] INFO: [Epoch 4] Val_loss=0.3174 | Val_Macro-F1=0.6335
# ...

# %%
# !zip -r checkpoints.zip ./checkpoints
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/best_model_Seq2Seq.pt (deflated 8%)
#   adding: checkpoints/best_model_Seq2Seq_Bahdanau.pt (deflated 7%)
#   adding: checkpoints/best_model_Seq2Seq_Luong.pt (deflated 8%)
