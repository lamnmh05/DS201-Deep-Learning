# %%
# !python main.py
# Out:
# 00:19:57 - INFO - Using cpu device
# 00:19:59 - INFO - Training model with 1 hidden layer...
#
# ...
# Epoch 1/5:  32%|███▏      | 594/1875 [00:01<00:02, 504.40batch/s, loss=2.3634]
# ...
# ...
# Epoch 5/5: 100%|██████████| 1875/1875 [00:06<00:00, 275.38batch/s, loss=1.4994]
# 00:21:30 - INFO - Epoch 5/5 finished | Average loss: 1.4994
#
# ...
# Evaluating: 100%|██████████| 10000/10000 [00:04<00:00, 2035.53it/s]
# 00:21:35 - INFO - Metrics for model with 3 hidden layers: {'accuracy': 0.963, 'f1': 0.9627577976469773, 'precision': 0.9634210115430333, 'recall': 0.9624519555531672}
